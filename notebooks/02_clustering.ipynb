# %%
import pandas as pd
import psycopg2
import sys
import pandas
import math
from pandas.io import sql
import sqlalchemy
from sqlalchemy import create_engine
from datetime import datetime
import os
from configobj import ConfigObj
import contextlib

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from functions.utils import database

# %%
## define paths and variables

config_path = "/home/jovyan/shared/rural_planner_refactoring/config_files_test/config_co"

parser = ConfigObj(config_path)

sql_path =  parser['sql_path']
country_folder = parser['country_folder']
schema = parser['clustering_params']['schema']


output_table = parser['clustering_params']['output_table']
table_transport = parser['clustering_params']['table_transport']
table_infrastructure = parser['clustering_params']['table_infrastructure']
table_settlements = parser['clustering_params']['table_settlements']
table_coverage = parser['clustering_params']['table_coverage']
table_franchises = parser['clustering_params']['table_franchises']
table_nodes_original = parser['clustering_params']['table_nodes_original']
table_nodes = parser['clustering_params']['table_nodes']
table_schools   = parser['clustering_params']['table_schools']

radius = int(parser['clustering_params']['max_coverage_radius'])

# %%
#Create node table

query_path = sql_path + '/' + country_folder + '/' + 'clustering_create_node_table.sql'

with open(query_path) as file, database(parser) as db:
    query = file.read()
    query_formatted = query.format(schema = schema,
                               table_coverage = table_coverage,
                               table_settlements = table_settlements,
                               table_infrastructure = table_infrastructure,
                               table_nodes_original = table_nodes_original,
                               table_franchises = table_franchises,
                               table_transport = table_transport)
    db.execute(query_formatted)

# %%
#Create node table copy

query_path = sql_path + '/' + 'clustering_create_node_table_copy.sql'

with open(query_path) as file, database(parser) as db:
    query = file.read()
    query_formatted = query.format(schema = schema,
                                   table_nodes = table_nodes,
                               table_nodes_original = table_nodes_original)
    db.execute(query_formatted)

# %%
# Generate clusters with tx

query_path = sql_path + '/' + country_folder + '/' + 'clustering_towers_priority_1.sql'

with open(query_path) as file, database(parser) as db:
    query = file.read()
    query_formatted = query.format(schema = schema,
                             table_nodes = table_nodes,
                             radius = radius,
                             table_infrastructure = table_infrastructure,
                             table_coverage = table_coverage)
    clusters_towers_p1 = pd.read_sql_query(query_formatted, db)

# %%
# Delete already assigned nodes from node_table

query_path = sql_path + '/' + 'clustering_delete_assigned_nodes.sql'

excluded_ids = ''    

for i in range(0, len(clusters_towers_p1)-1):
    if (clusters_towers_p1.iloc[i]['nodes'] == ''):
        nodes = '\', '
    else:
        nodes = '\', ' + clusters_towers_p1.iloc[i]['nodes'] + ', '
    excluded_ids =   excluded_ids +  ' \'' + clusters_towers_p1.iloc[i]['centroid'] + nodes

if (clusters_towers_p1.iloc[i]['nodes'] == ''):
    nodes_end = ''
else:
    nodes_end = clusters_towers_p1.iloc[len(clusters_towers_p1)-1]['nodes'] + ', '
excluded_ids =   excluded_ids + nodes_end + ' \'' + clusters_towers_p1.iloc[len(clusters_towers_p1)-1]['centroid']+ '\''

with open(query_path) as file, database(parser) as db:
    query = file.read()
    query_formatted = query.format(schema = schema,
                             table_nodes = table_nodes,
                             excluded_ids = excluded_ids)
    db.execute(query_formatted)

# %%
#Clustering for towers with no tx

query_path = sql_path + '/' + country_folder + '/' + 'clustering_towers_priority_2.sql'

with open(query_path) as file, database(parser) as db:
    query = file.read()
    query_formatted = query.format(schema = schema,
                             table_nodes = table_nodes,
                             radius = radius,
                             table_infrastructure = table_infrastructure,
                             table_coverage = table_coverage)
    clusters_towers_p2 = pd.read_sql_query(query_formatted, db)

# %%
# Delete already assigned nodes from node_table

query_path = sql_path + '/' + 'clustering_delete_assigned_nodes.sql'

excluded_ids = ''

for i in range(0, len(clusters_towers_p2)-1):
    if (clusters_towers_p2.iloc[i]['nodes'] == ''):
        nodes = '\', '
    else:
        nodes = '\', ' + clusters_towers_p2.iloc[i]['nodes'] + ', '
    excluded_ids =   excluded_ids +  ' \'' + clusters_towers_p2.iloc[i]['centroid'] + nodes

if (clusters_towers_p2.iloc[i]['nodes'] == ''):
    nodes_end = ''
else:
    nodes_end = clusters_towers_p2.iloc[len(clusters_towers_p2)-1]['nodes'] + ', '
excluded_ids =   excluded_ids + nodes_end + ' \'' + clusters_towers_p2.iloc[len(clusters_towers_p2)-1]['centroid']+ '\''

with open(query_path) as file, database(parser) as db:
    query = file.read()
    query_formatted = query.format(schema = schema,
                             table_nodes = table_nodes,
                             excluded_ids = excluded_ids)
    db.execute(query_formatted)

# %%
#Delete nodes that are towers

query_path = sql_path + '/' + country_folder + '/' + 'clustering_delete_unwanted_nodes.sql'

with open(query_path) as file, database(parser) as db:
    query = file.read()
    query_formatted = query.format(schema = schema,
                                   table_nodes = table_nodes)
    db.execute(query_formatted)

# %%
#Clustering for SETTLEMENTS

query_path = sql_path + '/' + country_folder + '/' + 'clustering_settlements.sql'
del_query_path = sql_path + '/' + 'clustering_delete_assigned_nodes.sql'

with open(query_path) as file, open(del_query_path) as del_file, database(parser) as db:
    query = file.read()
    query_formatted = query.format(schema = schema,
                             table_nodes = table_nodes,
                             table_coverage = table_coverage,
                             table_franchises = table_franchises,
                             table_schools = table_schools,
                             radius = radius)
    
    del_query = del_file.read()
    del_query_formatted = del_query.format(schema = schema, 
                             table_nodes = table_nodes,
                            excluded_ids = excluded_ids)
    
    df_clusters_int = pd.read_sql_query(query_formatted, db)
    clusters_greenfield = pd.DataFrame(columns = df_clusters_int.columns)

    num_nodes = 0
    excluded_ids = ''
    
    #We cluster the rest of nodes iteratively
    i = 0
    while(not df_clusters_int.empty):
        i = i + 1

        excluded_ids = df_clusters_int.iloc[0]['nodes'] + ', \'' + df_clusters_int.iloc[0]['centroid'] + '\''

        del_query_formatted=del_query.format(schema = schema, 
                                 table_nodes = table_nodes,
                                excluded_ids = excluded_ids)

        db.execute(del_query_formatted) 

        num_nodes = num_nodes + df_clusters_int.iloc[0]['cluster_size']

        clusters_greenfield = clusters_greenfield.append(df_clusters_int, ignore_index=True)

        df_clusters_int = pd.read_sql_query(query_formatted,con=db)

        if(i%10 == 0):
            print(str(datetime.now()))
            print("Iteration " + str(i) + " with " + str(num_nodes) + " nodes clustered.")
            print(df_clusters_int)
# Out:
# 2020-02-17 10:58:23.398236
# Iteration 10 with 65 nodes clustered.
#            centroid          centroid_type  centroid_weight  \
# 0  N4D4975-W69D7922  SETTLEMENT GREENFIELD       144.774516
#
#                                                nodes  cluster_weight  \
# 0  '99773000' ,'N4D5086-W69D8097' ,'N4D5194-W69D8...     8258.401332
#
#    cluster_size
# 0             4
# 2020-02-17 10:58:26.127640
# Iteration 20 with 114 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  76364014  SETTLEMENT GREENFIELD      3326.217426  '76364011' ,'76364018'
#
#    cluster_weight  cluster_size
# 0     6576.592761             3
# 2020-02-17 10:58:28.626244
# Iteration 30 with 151 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  19517044  SETTLEMENT GREENFIELD      1092.833096
#
#                                                nodes  cluster_weight  \
# 0  '19517030' ,'19517032' ,'19517034' ,'19517035'...     5206.466847
#
#    cluster_size
# 0             7
# 2020-02-17 10:58:31.076299
# Iteration 40 with 200 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  47692006  SETTLEMENT GREENFIELD       461.954959
#
#                                             nodes  cluster_weight  \
# 0  '47318003' ,'47318008' ,'47692003' ,'47692011'     4875.082389
#
#    cluster_size
# 0             5
# 2020-02-17 10:58:33.502062
# Iteration 50 with 246 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  52838018  SETTLEMENT GREENFIELD      1342.394665
#
#                                                nodes  cluster_weight  \
# 0  '52320001' ,'52838020' ,'N1D2003-W77D5725' ,'N...     4538.222586
#
#    cluster_size
# 0             6
# 2020-02-17 10:58:35.893870
# Iteration 60 with 285 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  52233008  SETTLEMENT GREENFIELD      2000.538117
#
#                                 nodes  cluster_weight  cluster_size
# 0  '52233001' ,'52233011' ,'52540004'     4374.040379             4
# 2020-02-17 10:58:38.270516
# Iteration 70 with 322 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  54313000  SETTLEMENT GREENFIELD           2658.0
#
#                                             nodes  cluster_weight  \
# 0  '54313005' ,'54313006' ,'54313007' ,'54680002'     4086.376221
#
#    cluster_size
# 0             5
# 2020-02-17 10:58:40.629794
# Iteration 80 with 375 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  25862002  SETTLEMENT GREENFIELD      1137.590244
#
#                                 nodes  cluster_weight  cluster_size
# 0  '25862001' ,'25862004' ,'25862005'     3921.692683             4
# 2020-02-17 10:58:42.960127
# Iteration 90 with 411 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  52687001  SETTLEMENT GREENFIELD      1078.626794
#
#                                                nodes  cluster_weight  \
# 0  '52399030' ,'52687002' ,'52687005' ,'52687008'...     3772.248196
#
#    cluster_size
# 0             6
# 2020-02-17 10:58:45.269296
# Iteration 100 with 451 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  52320009  SETTLEMENT GREENFIELD       383.765782  '52885004'
#
#    cluster_weight  cluster_size
# 0     3621.306871             2
# 2020-02-17 10:58:47.561210
# Iteration 110 with 489 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  27025003  SETTLEMENT GREENFIELD          1167.36  '27025017' ,'27025040'
#
#    cluster_weight  cluster_size
# 0         3502.08             3
# 2020-02-17 10:58:49.826028
# Iteration 120 with 535 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  23001044  SETTLEMENT GREENFIELD       769.901731
#
#                                             nodes  cluster_weight  \
# 0  '23001015' ,'23001019' ,'23001042' ,'23001050'     3356.771547
#
#    cluster_size
# 0             5
# 2020-02-17 10:58:52.067950
# Iteration 130 with 572 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  19824004  SETTLEMENT GREENFIELD       546.244334  '19824003'
#
#    cluster_weight  cluster_size
# 0     3193.428413             2
# 2020-02-17 10:58:54.268123
# Iteration 140 with 611 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  70235007  SETTLEMENT GREENFIELD        225.82288
#
#                                                nodes  cluster_weight  \
# 0  '70235003' ,'70235008' ,'70235011' ,'70678007'...     3018.685245
#
#    cluster_size
# 0             7
# 2020-02-17 10:58:56.444920
# Iteration 150 with 653 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  27660005  SETTLEMENT GREENFIELD            723.8
#
#                                 nodes  cluster_weight  cluster_size
# 0  '27660003' ,'27660006' ,'27660015'          2895.2             4
# 2020-02-17 10:58:58.487184
# Iteration 160 with 688 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  95025011  SETTLEMENT GREENFIELD         706.5625  '95025001'
#
#    cluster_weight  cluster_size
# 0     2800.081019             2
# 2020-02-17 10:58:59.960032
# Iteration 170 with 720 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  52693011  SETTLEMENT GREENFIELD       485.209178
#
#                                 nodes  cluster_weight  cluster_size
# 0  '19100014' ,'52693001' ,'52693014'     2701.581642             4
# 2020-02-17 10:59:01.429682
# Iteration 180 with 756 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  05138002  SETTLEMENT GREENFIELD      1418.904255  '05138005'
#
#    cluster_weight  cluster_size
# 0     2639.024823             2
# 2020-02-17 10:59:02.888975
# Iteration 190 with 785 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  41668003  SETTLEMENT GREENFIELD        809.27187  '41668004' ,'41668007'
#
#    cluster_weight  cluster_size
# 0     2537.645364             3
# 2020-02-17 10:59:04.324086
# Iteration 200 with 823 nodes clustered.
#            centroid          centroid_type  centroid_weight  \
# 0  N8D9103-W75D9610  SETTLEMENT GREENFIELD       110.487366
#
#                                         nodes  cluster_weight  cluster_size
# 0  '23162005' ,'23162024' ,'N8D8910-W75D9738'     2493.372756             4
# 2020-02-17 10:59:05.785925
# Iteration 210 with 861 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  25596004  SETTLEMENT GREENFIELD      1937.772762  '25580002'
#
#    cluster_weight  cluster_size
# 0     2445.443713             2
# 2020-02-17 10:59:07.194902
# Iteration 220 with 899 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  76122011  SETTLEMENT GREENFIELD       287.635509
#
#                                             nodes  cluster_weight  \
# 0  '63302001' ,'76122001' ,'76736005' ,'76736010'     2338.775913
#
#    cluster_size
# 0             5
# 2020-02-17 10:59:08.576020
# Iteration 230 with 934 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  05125000  SETTLEMENT GREENFIELD           1669.0
#
#                                                nodes  cluster_weight  \
# 0  'N6D4382-W75D9579' ,'N6D4497-W75D9852' ,'N6D45...     2303.622642
#
#    cluster_size
# 0             5
# 2020-02-17 10:59:09.935244
# Iteration 240 with 963 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  86885002  SETTLEMENT GREENFIELD      1669.333333  '86885007'
#
#    cluster_weight  cluster_size
# 0     2277.944444             2
# 2020-02-17 10:59:11.300929
# Iteration 250 with 991 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  23660066  SETTLEMENT GREENFIELD       137.014566
#
#                                             nodes  cluster_weight  \
# 0  '23660015' ,'23660025' ,'23660058' ,'23660061'     2218.582014
#
#    cluster_size
# 0             5
# 2020-02-17 10:59:12.666020
# Iteration 260 with 1029 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  13810008  SETTLEMENT GREENFIELD       249.734564  '13810011'
#
#    cluster_weight  cluster_size
# 0     2140.581973             2
# 2020-02-17 10:59:13.993065
# Iteration 270 with 1056 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  05002015  SETTLEMENT GREENFIELD       932.574442  '05002012' ,'05376001'
#
#    cluster_weight  cluster_size
# 0     2063.015509             3
# 2020-02-17 10:59:15.285277
# Iteration 280 with 1091 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  47555018  SETTLEMENT GREENFIELD       565.646018  '47555005' ,'47555009'
#
#    cluster_weight  cluster_size
# 0     1983.982301             3
# 2020-02-17 10:59:16.562010
# Iteration 290 with 1118 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  19760001  SETTLEMENT GREENFIELD        545.98081  '19392002' ,'19760012'
#
#    cluster_weight  cluster_size
# 0     1901.309526             3
# 2020-02-17 10:59:17.831769
# Iteration 300 with 1148 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  52473025  SETTLEMENT GREENFIELD       308.870748
#
#                                                nodes  cluster_weight  \
# 0  '52390001' ,'52390003' ,'52473010' ,'52473027'...     1841.015401
#
#    cluster_size
# 0             6
# 2020-02-17 10:59:19.084366
# Iteration 310 with 1180 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  13655005  SETTLEMENT GREENFIELD      1169.019074  '13655007'
#
#    cluster_weight  cluster_size
# 0     1795.019074             2
# 2020-02-17 10:59:20.329751
# Iteration 320 with 1208 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  05543001  SETTLEMENT GREENFIELD       579.392924  '05628007'
#
#    cluster_weight  cluster_size
# 0     1764.969361             2
# 2020-02-17 10:59:21.560984
# Iteration 330 with 1238 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  19517016  SETTLEMENT GREENFIELD       649.018782  '19517039'
#
#    cluster_weight  cluster_size
# 0     1727.535287             2
# 2020-02-17 10:59:22.795387
# Iteration 340 with 1265 nodes clustered.
#             centroid  centroid_type  centroid_weight                   nodes  \
# 0  N11D4857-W72D7783  SETTLEMENT 2G        73.078059  '44560011' ,'44560013'
#
#    cluster_weight  cluster_size
# 0      1643.23588             3
# 2020-02-17 10:59:24.017142
# Iteration 350 with 1292 nodes clustered.
#    centroid  centroid_type  centroid_weight       nodes  cluster_weight  \
# 0  41306005  SETTLEMENT 2G       322.456466  '41306004'     1626.003879
#
#    cluster_size
# 0             2
# 2020-02-17 10:59:25.216961
# Iteration 360 with 1317 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  70771027  SETTLEMENT GREENFIELD       143.769376  '70771005' ,'70771018'
#
#    cluster_weight  cluster_size
# 0      1587.99811             3
# 2020-02-17 10:59:26.416932
# Iteration 370 with 1342 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  70678038  SETTLEMENT GREENFIELD       532.251769  '70678002' ,'70678035'
#
#    cluster_weight  cluster_size
# 0     1553.432488             3
# 2020-02-17 10:59:27.601808
# Iteration 380 with 1368 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  52621029  SETTLEMENT GREENFIELD       753.521368  '52621026'
#
#    cluster_weight  cluster_size
# 0     1507.042735             2
# 2020-02-17 10:59:28.779879
# Iteration 390 with 1398 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  70265006  SETTLEMENT GREENFIELD       743.565547  '70265002'
#
#    cluster_weight  cluster_size
# 0     1487.131094             2
# 2020-02-17 10:59:29.948575
# Iteration 400 with 1422 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  23068003  SETTLEMENT GREENFIELD       811.278126  '70708029'
#
#    cluster_weight  cluster_size
# 0     1449.912814             2
# 2020-02-17 10:59:31.104366
# Iteration 410 with 1447 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  70678025  SETTLEMENT GREENFIELD        259.93691  '70124004' ,'70678027'
#
#    cluster_weight  cluster_size
# 0     1417.850159             3
# 2020-02-17 10:59:32.471901
# Iteration 420 with 1476 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  23686001  SETTLEMENT GREENFIELD       358.097905
#
#                             nodes  cluster_weight  cluster_size
# 0  '23686027' ,'N9D0690-W76D0637'     1396.062847             3
# 2020-02-17 10:59:33.611021
# Iteration 430 with 1504 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  54660005  SETTLEMENT GREENFIELD       742.691241  '54660001'
#
#    cluster_weight  cluster_size
# 0     1362.222628             2
# 2020-02-17 10:59:34.741061
# Iteration 440 with 1530 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  11001013  SETTLEMENT GREENFIELD       693.203016
#
#                             nodes  cluster_weight  cluster_size
# 0  '11001007' ,'N4D3839-W74D1398'     1335.528746             3
# 2020-02-17 10:59:35.873473
# Iteration 450 with 1561 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  23001029  SETTLEMENT GREENFIELD       129.343491
#
#                                 nodes  cluster_weight  cluster_size
# 0  '23001067' ,'23555029' ,'23555030'     1290.894709             4
# 2020-02-17 10:59:37.008900
# Iteration 460 with 1589 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  52696016  SETTLEMENT GREENFIELD       215.839572  '52696009' ,'52696017'
#
#    cluster_weight  cluster_size
# 0     1264.203209             3
# 2020-02-17 10:59:38.147384
# Iteration 470 with 1613 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  27160007  SETTLEMENT GREENFIELD       412.111111  '27160008' ,'27160009'
#
#    cluster_weight  cluster_size
# 0     1236.333333             3
# 2020-02-17 10:59:39.237920
# Iteration 480 with 1637 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  05234017  SETTLEMENT GREENFIELD       400.436019  '05234008' ,'05234015'
#
#    cluster_weight  cluster_size
# 0     1201.308057             3
# 2020-02-17 10:59:40.325614
# Iteration 490 with 1662 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  76670002  SETTLEMENT GREENFIELD       589.579399  '76670024'
#
#    cluster_weight  cluster_size
# 0     1179.158798             2
# 2020-02-17 10:59:41.430537
# Iteration 500 with 1695 nodes clustered.
#            centroid          centroid_type  centroid_weight  \
# 0  N7D3679-W76D8514  SETTLEMENT GREENFIELD        84.704306
#
#                                             nodes  cluster_weight  \
# 0  '27615034' ,'27615039' ,'27615046' ,'27615047'     1149.558444
#
#    cluster_size
# 0             5
# 2020-02-17 10:59:42.515531
# Iteration 510 with 1721 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  25653003  SETTLEMENT GREENFIELD       425.362216  '25653005'
#
#    cluster_weight  cluster_size
# 0     1099.397727             2
# 2020-02-17 10:59:43.573905
# Iteration 520 with 1746 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  27491018  SETTLEMENT GREENFIELD       599.041139  '27491001' ,'27491008'
#
#    cluster_weight  cluster_size
# 0     1072.357595             3
# 2020-02-17 10:59:44.620532
# Iteration 530 with 1773 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  66687006  SETTLEMENT GREENFIELD       514.476949  '66687005'
#
#    cluster_weight  cluster_size
# 0     1043.378486             2
# 2020-02-17 10:59:45.678087
# Iteration 540 with 1798 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  25148012  SETTLEMENT GREENFIELD       797.359826  '25148005'
#
#    cluster_weight  cluster_size
# 0     1017.583016             2
# 2020-02-17 10:59:46.711052
# Iteration 550 with 1825 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  86568034  SETTLEMENT GREENFIELD       338.727841  '86568014' ,'86568019'
#
#    cluster_weight  cluster_size
# 0      988.288288             3
# 2020-02-17 10:59:47.744401
# Iteration 560 with 1853 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  19809027  SETTLEMENT GREENFIELD       278.511538
#
#                             nodes  cluster_weight  cluster_size
# 0  '19809011' ,'N2D7584-W77D4403'      960.384615             3
# 2020-02-17 10:59:48.760527
# Iteration 570 with 1876 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  13244017  SETTLEMENT GREENFIELD       239.029683  '13244016' ,'70713004'
#
#    cluster_weight  cluster_size
# 0      941.960464             3
# 2020-02-17 10:59:49.778056
# Iteration 580 with 1901 nodes clustered.
#             centroid  centroid_type  centroid_weight                   nodes  \
# 0  N11D2950-W73D9720  SETTLEMENT 2G         35.59669  '47001002' ,'47001032'
#
#    cluster_weight  cluster_size
# 0      923.140825             3
# 2020-02-17 10:59:50.780279
# Iteration 590 with 1929 nodes clustered.
#    centroid          centroid_type  centroid_weight                nodes  \
# 0  44001032  SETTLEMENT GREENFIELD       852.577358  'N11D4628-W72D7882'
#
#    cluster_weight  cluster_size
# 0      904.775972             2
# 2020-02-17 10:59:51.836435
# Iteration 600 with 1962 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  52835011  SETTLEMENT GREENFIELD       200.724528  '52835111' ,'52835215'
#
#    cluster_weight  cluster_size
# 0      888.922909             3
# 2020-02-17 10:59:52.833174
# Iteration 610 with 1984 nodes clustered.
#    centroid          centroid_type  centroid_weight               nodes  \
# 0  19809014  SETTLEMENT GREENFIELD       537.815385  'N2D8037-W77D7600'
#
#    cluster_weight  cluster_size
# 0      854.742308             2
# 2020-02-17 10:59:53.813175
# Iteration 620 with 2015 nodes clustered.
#    centroid          centroid_type  centroid_weight               nodes  \
# 0  19517025  SETTLEMENT GREENFIELD       758.779311  'N2D6311-W75D8745'
#
#    cluster_weight  cluster_size
# 0      830.362265             2
# 2020-02-17 10:59:54.777796
# Iteration 630 with 2043 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  23001035  SETTLEMENT GREENFIELD       326.438334  '23574009'
#
#    cluster_weight  cluster_size
# 0      803.928733             2
# 2020-02-17 10:59:55.746920
# Iteration 640 with 2066 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  91540006  SETTLEMENT GREENFIELD       177.646444  '91540003' ,'91540016'
#
#    cluster_weight  cluster_size
# 0      782.960251             3
# 2020-02-17 10:59:56.709131
# Iteration 650 with 2093 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  50711012  SETTLEMENT GREENFIELD       419.233622
#
#                             nodes  cluster_weight  cluster_size
# 0  '50683012' ,'N3D1839-W73D8747'      772.340378             3
# 2020-02-17 10:59:57.663068
# Iteration 660 with 2118 nodes clustered.
#            centroid          centroid_type  centroid_weight  \
# 0  N4D3582-W69D3173  SETTLEMENT GREENFIELD       183.381053
#
#                                                nodes  cluster_weight  \
# 0  'N4D3610-W69D3370' ,'N4D3628-W69D2744' ,'N4D37...      752.827482
#
#    cluster_size
# 0             4
# 2020-02-17 10:59:58.818537
# Iteration 670 with 2145 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  68255008  SETTLEMENT GREENFIELD          163.285  '68255002' ,'68255007'
#
#    cluster_weight  cluster_size
# 0         739.585             3
# 2020-02-17 10:59:59.734839
# Iteration 680 with 2169 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  76563009  SETTLEMENT GREENFIELD       131.574749
#
#                                 nodes  cluster_weight  cluster_size
# 0  '76563007' ,'76563008' ,'76563025'      712.318467             4
# 2020-02-17 11:00:00.671900
# Iteration 690 with 2193 nodes clustered.
#    centroid          centroid_type  centroid_weight  \
# 0  76126008  SETTLEMENT GREENFIELD       306.190476
#
#                             nodes  cluster_weight  cluster_size
# 0  '76126007' ,'N4D0296-W76D4052'      694.683744             3
# 2020-02-17 11:00:01.648580
# Iteration 700 with 2218 nodes clustered.
#            centroid          centroid_type  centroid_weight  \
# 0  N5D9808-W74D4819  SETTLEMENT GREENFIELD       143.989598
#
#                             nodes  cluster_weight  cluster_size
# 0  '15572021' ,'N6D0028-W74D4887'      677.598109             3
# 2020-02-17 11:00:02.559263
# Iteration 710 with 2241 nodes clustered.
#    centroid          centroid_type  centroid_weight                   nodes  \
# 0  41001035  SETTLEMENT GREENFIELD       105.519968  '41001005' ,'41001015'
#
#    cluster_weight  cluster_size
# 0      660.476837             3
# 2020-02-17 11:00:03.477835
# Iteration 720 with 2271 nodes clustered.
#    centroid  centroid_type  centroid_weight       nodes  cluster_weight  \
# 0  70265013  SETTLEMENT 2G       438.825569  '70265008'      637.131935
#
#    cluster_size
# 0             2
# 2020-02-17 11:00:04.373465
# Iteration 730 with 2294 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  52835211  SETTLEMENT GREENFIELD       200.724528  '52835109'
#
#    cluster_weight  cluster_size
# 0      611.731895             2
# 2020-02-17 11:00:05.239521
# Iteration 740 with 2316 nodes clustered.
#             centroid          centroid_type  centroid_weight  \
# 0  N12D0206-W71D1810  SETTLEMENT GREENFIELD       232.805252
#
#                                       nodes  cluster_weight  cluster_size
# 0  'N12D0152-W71D1525' ,'N12D0285-W71D1988'      592.595186             3
# 2020-02-17 11:00:06.114774
# Iteration 750 with 2339 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  05893015  SETTLEMENT GREENFIELD       282.315117  '05893005'
#
#    cluster_weight  cluster_size
# 0      564.630234             2
# 2020-02-17 11:00:06.966553
# Iteration 760 with 2362 nodes clustered.
#            centroid          centroid_type  centroid_weight  \
# 0  N7D3265-W76D7652  SETTLEMENT GREENFIELD         2.604869
#
#                                                nodes  cluster_weight  \
# 0  '27615036' ,'N7D3214-W76D7658' ,'N7D3277-W76D7...      542.255454
#
#    cluster_size
# 0             4
# 2020-02-17 11:00:07.810847
# Iteration 770 with 2391 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  52540003  SETTLEMENT GREENFIELD       269.346522  '52540010'
#
#    cluster_weight  cluster_size
# 0      529.405233             2
# 2020-02-17 11:00:09.412443
# Iteration 780 with 2412 nodes clustered.
#            centroid          centroid_type  centroid_weight  \
# 0  N2D2939-W76D0365  SETTLEMENT GREENFIELD       289.763482
#
#                 nodes  cluster_weight  cluster_size
# 0  'N2D2907-W76D0778'      513.122832             2
# 2020-02-17 11:00:10.237940
# Iteration 790 with 2438 nodes clustered.
#            centroid          centroid_type  centroid_weight       nodes  \
# 0  N7D1300-W72D7295  SETTLEMENT GREENFIELD        53.918702  '54743002'
#
#    cluster_weight  cluster_size
# 0      487.095802             2
# 2020-02-17 11:00:11.052622
# Iteration 800 with 2460 nodes clustered.
#    centroid          centroid_type  centroid_weight               nodes  \
# 0  70771002  SETTLEMENT GREENFIELD       365.958412  'N8D6874-W74D8563'
#
#    cluster_weight  cluster_size
# 0      458.793023             2
# 2020-02-17 11:00:12.290490
# Iteration 810 with 2485 nodes clustered.
#            centroid          centroid_type  centroid_weight       nodes  \
# 0  N2D2511-W76D8998  SETTLEMENT GREENFIELD        93.598057  '19256013'
#
#    cluster_weight  cluster_size
# 0       448.86962             2
# 2020-02-17 11:00:14.443083
# Iteration 820 with 2506 nodes clustered.
#            centroid          centroid_type  centroid_weight  \
# 0  N3D5492-W69D6975  SETTLEMENT GREENFIELD       121.232432
#
#                                     nodes  cluster_weight  cluster_size
# 0  'N3D5469-W69D7130' ,'N3D5487-W69D7097'      437.783784             3
# 2020-02-17 11:00:17.065798
# Iteration 830 with 2528 nodes clustered.
#            centroid          centroid_type  centroid_weight  \
# 0  N8D3445-W74D1682  SETTLEMENT GREENFIELD       242.408023
#
#                 nodes  cluster_weight  cluster_size
# 0  'N8D3806-W74D1946'      399.710776             2
# 2020-02-17 11:00:20.049419
# Iteration 840 with 2551 nodes clustered.
#            centroid  centroid_type  centroid_weight       nodes  \
# 0  N3D8913-W73D6303  SETTLEMENT 2G       188.893126  '50006006'
#
#    cluster_weight  cluster_size
# 0      382.961407             2
# 2020-02-17 11:00:22.163688
# Iteration 850 with 2573 nodes clustered.
#            centroid          centroid_type  centroid_weight  \
# 0  N1D8208-W75D8168  SETTLEMENT GREENFIELD        62.001842
#
#                                                nodes  cluster_weight  \
# 0  'N1D8032-W75D8211' ,'N1D8240-W75D8182' ,'N1D84...       364.71672
#
#    cluster_size
# 0             4
# 2020-02-17 11:00:24.963511
# Iteration 860 with 2596 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  76109035  SETTLEMENT GREENFIELD        160.23949  '76109090'
#
#    cluster_weight  cluster_size
# 0       345.13121             2
# 2020-02-17 11:00:26.461747
# Iteration 870 with 2618 nodes clustered.
#            centroid  centroid_type  centroid_weight               nodes  \
# 0  N8D8742-W75D9568  SETTLEMENT 2G       135.502705  'N8D8873-W75D9637'
#
#    cluster_weight  cluster_size
# 0      326.438334             2
# 2020-02-17 11:00:27.761887
# Iteration 880 with 2640 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  50573011  SETTLEMENT GREENFIELD       174.650091  '50573007'
#
#    cluster_weight  cluster_size
# 0      306.960766             2
# 2020-02-17 11:00:29.853081
# Iteration 890 with 2661 nodes clustered.
#    centroid          centroid_type  centroid_weight       nodes  \
# 0  05873011  SETTLEMENT GREENFIELD       127.930902  '27099011'
#
#    cluster_weight  cluster_size
# 0      276.815517             2
# 2020-02-17 11:00:31.272674
# Iteration 900 with 2681 nodes clustered.
#            centroid          centroid_type  centroid_weight  \
# 0  N8D1752-W76D7251  SETTLEMENT GREENFIELD       124.657013
#
#                 nodes  cluster_weight  cluster_size
# 0  'N8D1786-W76D7174'      241.981261             2
# 2020-02-17 11:00:32.135756
# Iteration 910 with 2703 nodes clustered.
#            centroid          centroid_type  centroid_weight  \
# 0  N0D6261-W76D8284  SETTLEMENT GREENFIELD       105.558261
#
#                 nodes  cluster_weight  cluster_size
# 0  'N0D5938-W76D8350'      211.116522             2
# 2020-02-17 11:00:32.867421
# Iteration 920 with 2728 nodes clustered.
#            centroid          centroid_type  centroid_weight  \
# 0  N8D3569-W76D3444  SETTLEMENT GREENFIELD       106.076027
#
#                 nodes  cluster_weight  cluster_size
# 0  'N8D3568-W76D3227'      183.865113             2
# 2020-02-17 11:00:33.621349
# Iteration 930 with 2749 nodes clustered.
#            centroid          centroid_type  centroid_weight  \
# 0  N1D8048-W75D9819  SETTLEMENT GREENFIELD        68.012048
#
#                 nodes  cluster_weight  cluster_size
# 0  'N1D7879-W75D9714'      158.694779             2
# 2020-02-17 11:00:34.396457
# Iteration 940 with 2769 nodes clustered.
#            centroid          centroid_type  centroid_weight  \
# 0  N7D0019-W77D2604  SETTLEMENT GREENFIELD         46.88764
#
#                 nodes  cluster_weight  cluster_size
# 0  'N6D9982-W77D2588'      117.219101             2
# 2020-02-17 11:00:35.116083
# Iteration 950 with 2790 nodes clustered.
#            centroid  centroid_type  centroid_weight               nodes  \
# 0  N6D8220-W71D1441  SETTLEMENT 2G        40.177435  'N6D8207-W71D1812'
#
#    cluster_weight  cluster_size
# 0       80.354869             2
# 2020-02-17 11:00:35.822913
# Iteration 960 with 2810 nodes clustered.
# Empty DataFrame
# Columns: [centroid, centroid_type, centroid_weight, nodes, cluster_weight, cluster_size]
# Index: []

# %%
#Create data frame with the unclustered nodes to include them as one-node clusters

query_path = sql_path + '/' + 'clustering_clusters_unclustered.sql'

with open(query_path) as file, database(parser) as db:
    query = file.read()
    query_formatted = query.format(schema = schema,
                                   table_nodes = table_nodes)
    clusters_unclustered = pd.read_sql_query(query_formatted, db)

# %%
clusters  = clusters_towers_p1.append(clusters_towers_p2, ignore_index=True).append(clusters_greenfield, ignore_index=True).append(clusters_unclustered, ignore_index=True)

# %%
#Create final data frame with all clusters        

query_path = sql_path + '/' + 'clustering_add_geom_clusters.sql'

with open(query_path) as file, database(parser) as db:    
    clusters.to_sql(output_table, con=db, if_exists = 'replace', schema = schema, index = False, 
                dtype = {'centroid_weight': sqlalchemy.types.Integer(),
                         'cluster_weight': sqlalchemy.types.Integer(),
                         'cluster_size': sqlalchemy.types.Integer()
                        })
    query = file.read()
    query_formatted = query.format(schema = schema,
                                   output_table = output_table,
                               table_nodes_original = table_nodes_original)
    db.execute(query_formatted)

# %%
#Create links data frame

query_path = sql_path + '/' + 'clustering_create_clusters_links.sql'

with open(query_path) as file, database(parser) as db:
    query = file.read()
    query_formatted = query.format(schema = schema,
                                   output_table = output_table,
                               table_nodes_original = table_nodes_original)
    db.execute(query_formatted)
